# %% [markdown]
# Provisional Schedule for 24th June 2024:
#
#     10-12:30pm Lecture:
#
#         Welcome
#
#         Introduction to MONAI and JADE
#
#         MONAI Components and Features
#
#         JADE and SLURM Jobs, Creating Containers
#
#         MONAI Optimisations for JADE/HPC Systems
#
#     12:30:pm-1:30pm: Lunch
#
#     1:30-4:30pm Group Activity
#
#     4:30pm wrap-up and discussion with focus on where to go next with MONAI
#
#     5pm onwards Refreshments
#
# * transforms
# * workflows
# * dataloaders
# * using multi-GPU components of Pytorch with all this

# %% [markdown]
# # Introduction to MONAI and JADE
# ## Biomedical Deep Learning on HPC systems
#
# ### Eric Kerfoot, King's College London, eric.kerfoot@kcl.ac.uk
# ### MONAI Developers, https://monai.io

# %% [markdown]
# * Introduction to MONAI
# * Brief overview of the whole project
# * Introduction to JADE and supercomputing
# * How does MONAI fit in

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## MONAI Resources:
#
# * Website: https://monai.io
# * Slack: https://forms.gle/QTxJq3hFictp31UM9
# * Docs:
#   * Core: https://docs.monai.io/en/stable/
#   * Label: https://docs.monai.io/projects/label/en/latest/index.html
#   * Deploy App SDK: https://docs.monai.io/projects/monai-deploy-app-sdk/en/latest
#
# * Github: https://github.com/Project-MONAI
#   * Core: https://github.com/Project-MONAI/MONAI
#   * Label: https://github.com/Project-MONAI/MONAILabel
#   * Deploy: https://github.com/Project-MONAI/monai-deploy

# %% [markdown]
# ## MONAI Resources:
#
# * YouTube: https://www.youtube.com/c/Project-MONAI
#   * Overview Videos, Deep Dive Series, Bootcamp and other event recordings
#
# * Twitter: https://twitter.com/ProjectMONAI
#   * Follow for the latest announcements
#
# * Medium: https://monai.medium.com
#   * Read about our latest releases and our upcoming research interview series
#
# * Easiest place to get help or ask questions is the issues in the repos, I get emails about practically everything

# %% [markdown]
# # JADE
#
#
#
# * Joint Academic Data science Endeavour (JADE)<div>
# <img style="float:right;" src="attachment:image.png" width="600"/>
# </div>
# * UK Tier-2 resource, funded by EPSRC, owned by the University of Oxford and hosted at the Hartree Centre
# * SLURM-based multinode supercomputing cluster with Tesla V100 GPUs

# %% [markdown]
# ## JADE For Us
# * (Assuming everyone here has an account)
# * JADE provides a lot of software packages, but we don't need to use any for MONAI necessarily
# * First objective is to set up a MONAI environment with Anaconda/Miniconda or Docker/Apptainer<img width="350" style="float:right;" src="https://vignette.wikia.nocookie.net/en.futurama/images/d/df/Slurmlogo.png/revision/latest?cb=20130724090249"/>
# * Next is to use the JADE environment efficiently and leverage MONAI components to do this
# * How to use SLURM effectively

# %% [markdown]
# ## JADE and MONAI
#
# * What we'll focus on today is how to use MONAI components to optimise the learning process of multi-GPU HPC machines like JADE
#   * Set up environment
#   * Choose strategy for loading data efficiently
#   * Best practices for using SLURM and where to put things in the file system
# * We'll cover a number of other best practice topics:
#   * Common optimisations
#   * Using bundles
#   * Multi-GPU training

# %% [markdown]
# ### Next: LIHE, MONAI Components
